# %% [markdown]
# ## What are modules?

# %% [markdown]
# #### consider a module to be the same as a code library

# %% [markdown]
# #### A file conatining a set of functions you want to include in your application.

# %% [markdown]
# #### Examples of python modules
# - Math
# - Random
# - OS
# - time

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.factorial(5)
# Out:
# 120

# %%
math.ceil(6.3)
# Out:
# 7

# %%
math.floor(6.9)
# Out:
# 6

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
import random

# %%
random.randint(1,6)
# Out:
# 3

# %%
a = [1, 2, 3, 4, 5]
random.shuffle(a)
a
# Out:
# [2, 5, 1, 4, 3]

# %%
import time

# %%
time.time()
# Out:
# 1776684056.0251842

# %%
time.ctime()
# Out:
# 'Mon Apr 20 16:51:12 2026'

# %%
print("hello")
time.sleep(1) # delay of 1 second
print("world")
# Out:
# hello
# world

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Gousemoddin\\Desktop\\onMyOwn\\Python\\Python_Topics'

# %%
os.listdir()
# Out:
# ['01_Print_Function.py',
#  '02_Data_Types.py',
#  '03_Comments.py',
#  '04_Variables.py',
#  '05_Keywords_&_Identifiers.py',
#  '06_Taking_User_Input.py',
#  '07_Literals.py',
#  '08_Operatots.py',
#  '09_If_Else_Statements.py',
#  '10_Indentation.py',
#  '11_Loops.py',
#  '12_Guess_Game.py',
#  '13_nested_loops.py',
#  '14_Break_Continue&pass.py',
#  '15_Built_in_Functions.py',
#  '16_Built_in_modules.ipynb']
